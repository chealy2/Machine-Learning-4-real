# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('Downloads/D3.csv')
data.head(4)
x1=data.values[:, [0]]
x2=data.values[:, [1]]
x3=data.values[:, [2]]
y=data.values[:, [3]]
m=len(y)
print(m)
# Out:
# 99

# %%
plt.scatter(x1,y,color='red',marker='*')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('x1')
plt.ylabel('y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
plt.scatter(x2,y,color='blue',marker='*')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('x2')
plt.ylabel('y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
plt.scatter(x3,y,color='black',marker='*')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('x3')
plt.ylabel('y')
plt.title('Scatter plot of training data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of training data')

# %%
X_0 = np.ones((m, 1))
X_1 = x1.reshape(m, 1)
X_2 = x2.reshape(m, 1)
X_3 = x3.reshape(m, 1)

Xs1 = np.hstack((X_0, X_1))
Xs2 = np.hstack((X_0, X_2))
Xs3 = np.hstack((X_0, X_3))

theta = np.random.randn(2,1)

# %%
def compute_cost_input1(Xs1, y, theta):
    predictions1 = Xs1.dot(theta) 
    errors1 = np.subtract(predictions1, y)   
    sqrErrors1 = np.square(errors1)   
    J1 = 1 / (2 * m) * np.sum(sqrErrors1) 

    return J1

# %%
def compute_cost_input2(Xs2, y, theta):
    predictions2 = Xs2.dot(theta) 
    errors2 = np.subtract(predictions2, y)   
    sqrErrors2 = np.square(errors2)   
    J2 = 1 / (2 * m) * np.sum(sqrErrors2) 
    
    return J2

# %%
def compute_cost_input3(Xs3, y, theta):
    predictions3 = Xs3.dot(theta) 
    errors3 = np.subtract(predictions3, y)   
    sqrErrors3 = np.square(errors3)   
    J3 = 1 / (2 * m) * np.sum(sqrErrors3) 
    
    return J3

# %%
cost1 = compute_cost_input1(Xs1, y, theta) 
print('The cost for given values of theta_0 and theta_1 =', cost1) 
theta = np.random.randn(2,1)

cost2 = compute_cost_input2(Xs2, y, theta) 
print('The cost for given values of theta_0 and theta_1 =', cost2) 
theta = np.random.randn(2,1)

cost3 = compute_cost_input3(Xs3, y, theta) 
print('The cost for given values of theta_0 and theta_1 =', cost3)
# Out:
# The cost for given values of theta_0 and theta_1 = 4.955018308940395
# The cost for given values of theta_0 and theta_1 = 3.639459840888914
# The cost for given values of theta_0 and theta_1 = 12.67481224906942

# %%
def gradient_descent(Xs1,y,theta,alpha,iterations):

    cost_history1 = np.zeros(iterations)

    for it in range(iterations):
        
        prediction = np.dot(Xs1,theta)
        
        theta = theta -(1/m)*alpha*( Xs1.T.dot((prediction - y)))
        
        cost_history1[it]  = compute_cost_input1(Xs1, y, theta) 
        
    return theta, cost_history1

# %%
def gradient_descent2(Xs2,y,theta2,alpha,iterations):

    cost_history2 = np.zeros(iterations)

    for it in range(iterations):
        
        prediction = np.dot(Xs2,theta)
        
        theta2 = theta2 -(1/m)*alpha*( Xs2.T.dot((prediction - y)))
        
        cost_history1[it]  = compute_cost_input1(Xs2, y, theta) 
        
    return theta2, cost_history2

# %%
def gradient_descent3(Xs3,y,theta3,alpha,iterations):

    cost_history3 = np.zeros(iterations)

    for it in range(iterations):
        
        prediction = np.dot(Xs3,theta)
        
        theta3 = theta3 -(1/m)*alpha*( Xs3.T.dot((prediction - y)))
        
        cost_history1[it]  = compute_cost_input1(Xs3, y, theta) 
        
    return theta3, cost_history3

# %%
theta = np.random.randn(2,1)
iterations=1500;
alpha=0.01;

theta, cost_history1 = gradient_descent(Xs1,y,theta,alpha,iterations)
print('Final value of theta =',theta)
print('cost_history =',cost_history1)
# Out:
# Final value of theta = [[ 5.7712932 ]
#  [-1.97649312]]
# cost_history = [8.43522955 7.98013602 7.57782746 ... 0.98850023 0.98847431 0.9884485 ]

# %%
plt.scatter(Xs1[:,1], y, color='red', marker= '+', label= 'Training Data') 
plt.plot(Xs1[:,1],Xs1.dot(theta), color='green', label='Linear Regression')  
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Xs1') 
plt.ylabel('y') 
plt.title('Linear Regression Fit') 
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history1, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J1)') 
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
theta2 = np.random.randn(2,1)
iterations=1500;
alpha=0.01;

theta2, cost_history2=gradient_descent2(Xs2,y,theta2,alpha,iterations)
print('Final value of theta =',theta2)
print('cost_history =',cost_history2)
# Out:
# Final value of theta = [[-0.44489674]
#  [50.75206829]]
# cost_history = [0. 0. 0. ... 0. 0. 0.]

# %%
plt.scatter(Xs2[:,1], y, color='red', marker= '+', label= 'Training Data') 
plt.plot(Xs2[:,1],Xs2.dot(theta2), color='green', label='Linear Regression')  
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Xs2') 
plt.ylabel('y') 
plt.title('Linear Regression Fit') 
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history2, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J2)') 
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
theta3 = np.random.randn(2,1)
iterations=1500;
alpha=0.01;

theta,cost_history3=gradient_descent3(Xs3,y,theta3,alpha,iterations)
print('Final value of theta =',theta3)
print('cost_history =',cost_history3)
# Out:
# Final value of theta = [[-0.19481519]
#  [ 0.18969429]]
# cost_history = [0. 0. 0. ... 0. 0. 0.]

# %%
plt.scatter(Xs3[:,1], y, color='red', marker= '+', label= 'Training Data') 
plt.plot(Xs3[:,1],Xs3.dot(theta3), color='green', label='Linear Regression')  
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Xs3') 
plt.ylabel('y') 
plt.title('Linear Regression Fit') 
plt.legend()

# %%
plt.plot(range(1, iterations + 1),cost_history3, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J3)') 
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
X_a=np.hstack((X_0, X_1))
X_b=np.hstack((X_a, X_2))
X_all=np.hstack((X_b, X_3))
theta4 = np.random.randn(4,1)
iterations=1500;
alpha=0.5;

# %%
def compute_cost_all(X_all, y, theta4):
    predictions4 = X_all.dot(theta4) 
    errors1 = np.subtract(predictions4, y)   
    sqrErrors1 = np.square(errors1)   
    J = 1 / (2 * m) * np.sum(sqrErrors1) 

    return J

# %%
cost4 = compute_cost_all(X_all, y, theta4) 
print('The cost for given values of theta_0, theta_1, theta_2, theta_3 and theta_4 =', cost4)
# Out:
# The cost for given values of theta_0, theta_1, theta_2, theta_3 and theta_4 = 40.3514502374037

# %%
def gradient_descent4(Xs1,y,theta,alpha,iterations):

    cost_history4 = np.zeros(iterations)

    for it in range(iterations):
        
        prediction = np.dot((X_all),theta4)
        
        theta = theta -(1/m)*alpha*( X_all.T.dot((prediction - y)))
        
        cost_history4[it]  = compute_cost_all(X_all, y, theta4) 
        
    return theta4, cost_history4

# %%
theta4, cost_history4=gradient_descent4(X_all,y,theta4,alpha,iterations)
print('Final value of theta =',theta4)
print('cost_history =',cost_history4)
# Out:
# Final value of theta = [[-0.52361139]
#  [-2.67085028]
#  [ 0.22159905]
#  [-0.7789979 ]]
# cost_history = [40.35145024 40.35145024 40.35145024 ... 40.35145024 40.35145024
#  40.35145024]

# %%
plt.plot(range(1, iterations + 1),cost_history4, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J)') 
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
predict1 = sum([1,1,1,1] * theta4);
print('Predicted value of y',predict1)

predict2 = sum([1,2,0,4] * theta4);
print('Predicted value of y',predict2)

predict3 = sum([1,3,2,1] * theta4);
print('Predicted value of y',predict3)
# Out:
# Predicted value of y [-3.75186052 -3.75186052 -3.75186052 -3.75186052]
# Predicted value of y [ -3.75186052  -7.50372105   0.         -15.00744209]
# Predicted value of y [ -3.75186052 -11.25558157  -7.50372105  -3.75186052]
